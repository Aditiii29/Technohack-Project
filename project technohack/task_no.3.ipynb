# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = "C:/Users/Hp/Downloads/Iris.csv"
data = pd.read_csv(file_path)

# Display the first  and last few rows of the dataset
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Create a histogram for the 'SepalLengthCm' feature
plt.figure(figsize=(10, 6))
plt.hist(iris_df['SepalLengthCm'], bins=20, edgecolor='black' )
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Create a histogram for the 'SepalWidthCm' feature
plt.figure(figsize=(10, 6))
plt.hist(iris_df['SepalWidthCm'], bins=20, edgecolor='black')
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Create a histogram for the 'PetalLengthCm' feature
plt.figure(figsize=(10, 6))
plt.hist(iris_df['PetalLengthCm'], bins=20, edgecolor='black')
plt.title('Distribution of Petal LengthCm')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Create a histogram for the 'PetalWidthCm' feature
plt.figure(figsize=(10, 6))
plt.hist(iris_df['PetalWidthCm'], bins=20, edgecolor='black')
plt.title('Distribution of Petal WidthCm')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Create a histogram for the 'Species' feature
plt.figure(figsize=(10, 6))
plt.hist(iris_df['Species'], bins=20, edgecolor='black')
plt.title('Distribution of Species')
plt.xlabel('Species (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
